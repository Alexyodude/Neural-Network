# %%
import json
import matplotlib.pyplot as plt

plotList0 = []
plotList1 = []
legendList = []
Start = 2
End = 5000

with open('data.json', 'r') as f:
    data = json.load(f)
    plotList0.append(data['correctHistory'][Start:End])
    plotList1.append(data['accuracyHistory'][Start:End])
    legendList.append('Current')

with open('data_67.json', 'r') as f:
    data1 = json.load(f)
    plotList0.append(data1['correctHistory'][Start:End])
    plotList1.append(data1['accuracyHistory'][Start:End])
    legendList.append('67%')

with open('data_lossSquareError2.json', 'r') as f:
    data2 = json.load(f)
    plotList0.append(data2['correctHistory'][Start:End])
    plotList1.append(data2['accuracyHistory'][Start:End])
    legendList.append('Square Error 2')

# with open('data_lossSquareErrorL=0.1.json', 'r') as f:
#     data3 = json.load(f)
#     plotList0.append(data3['correctHistory'][Start:End])
#     plotList1.append(data3['accuracyHistory'][Start:End])
#     legendList.append('Square Error L=0.1')

fig, axs = plt.subplots(3)
fig.suptitle('Correct and Accuracy History')
fig.legend(['Current', '67%', 'Square Error 2'])
for i in range(len(plotList0)):
    axs[0].plot(plotList0[i])
    axs[1].plot(plotList1[i])
axs[0].legend(legendList)
axs[1].legend(legendList)
fig.figure.set_size_inches(10, 10)
axs[0].set_xlabel('Epoch')
axs[1].set_xlabel('Epoch')
axs[0].set_ylabel('Correct History')
axs[1].set_ylabel('Accuracy History')
axs[2].plot(data['correctHistory'])
axs[2].plot(data['accuracyHistory'])
axs[2].legend(['Correct History', 'Accuracy History'])
plt.show()
